# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series y DataFrames en Pandas

# %%
psg_players = pd.Series(['Navas','Mbappe','Neymar','Messi'], index=[1,7,10,30])
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dict = {1: 'Navas', 7: 'Mbappe', 10: 'Neymar', 30:'Messi'}
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[7]
# Out:
# 'Mbappe'

# %%
psg_players[0:3]
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# dtype: object

# %%
dict = {'Jugador':['Navas','Mbappe','Neymar','Messi'],
 'Altura':[183.0, 170.0, 170.0, 163.0],
  'Goles':[2, 200, 150, 500]}

# %%
df_players = pd.DataFrame(dict, index=[1,7,10,30])
df_players
# Out:
#    Jugador  Altura  Goles
# 1    Navas   183.0      2
# 7   Mbappe   170.0    200
# 10  Neymar   170.0    150
# 30   Messi   163.0    500

# %%
df_players.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %%
df_players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')

# %% [markdown]
# # Filtrado con loc y iloc

# %% [markdown]
# ## loc

# %%
df_players.loc[:]
# Out:
#    Jugador  Altura  Goles
# 1    Navas   183.0      2
# 7   Mbappe   170.0    200
# 10  Neymar   170.0    150
# 30   Messi   163.0    500

# %%
df_players.loc[0:7]
# Out:
#   Jugador  Altura  Goles
# 1   Navas   183.0      2
# 7  Mbappe   170.0    200

# %%
df_players.loc[0:4, ['Jugador', 'Goles']]
# Out:
#   Jugador  Goles
# 1   Navas      2

# %% [markdown]
# ## iloc

# %%
df_players.iloc[:]
# Out:
#    Jugador  Altura  Goles
# 1    Navas   183.0      2
# 7   Mbappe   170.0    200
# 10  Neymar   170.0    150
# 30   Messi   163.0    500

# %%
df_players.iloc[2]
# Out:
# Jugador    Neymar
# Altura      170.0
# Goles         150
# Name: 10, dtype: object

# %% [markdown]
# # Agregar o eliminar datos con Pandas

# %%
# muestra las primeras 5 lineas del dataFrame
df_players.head()
# Out:
#    Jugador  Altura  Goles
# 1    Navas   183.0      2
# 7   Mbappe   170.0    200
# 10  Neymar   170.0    150
# 30   Messi   163.0    500

# %%
# #elimina la columna Altura de la salida pero no del dataFrame
df_players.drop('Altura', axis=1).head()
# Out:
#    Jugador  Goles
# 1    Navas      2
# 7   Mbappe    200
# 10  Neymar    150
# 30   Messi    500

# %%
# elimina la columna Altura del dataFrame
del df_players['Altura']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Altura'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_players
# Out:
#    Jugador  Goles
# 1    Navas      2
# 7   Mbappe    200
# 10  Neymar    150
# 30   Messi    500

# %%
df_players.drop([30], axis=0)
# Out:
#    Jugador  Goles
# 1    Navas      2
# 7   Mbappe    200
# 10  Neymar    150

# %%
# Crea una nueva columna con el nombre de Nueva_columna de valores Nan
df_players['Nueva_columna'] = np.nan
df_players
# Out:
#    Jugador  Goles  Nueva_columna
# 1    Navas      2            NaN
# 7   Mbappe    200            NaN
# 10  Neymar    150            NaN
# 30   Messi    500            NaN

# %%
# Muestra el numero de filas que posee el dataFrame
df_players.shape[0]
# Out:
# 4

# %%
# Agregar valores a una nueva columna
data = np.arange(0, df_players.shape[0])
# Crear una nueva columna y agregar los valores almacenados en el array
df_players['Rango'] = data
df_players
# Out:
#    Jugador  Goles  Nueva_columna  Rango
# 1    Navas      2            NaN      0
# 7   Mbappe    200            NaN      1
# 10  Neymar    150            NaN      2
# 30   Messi    500            NaN      3

# %%
# Para añadir filas se utiliza la función append de Python añadiendo como parámetro una lista, diccionario o añadiendo los valores manualmente.

df_players.append(df_players)
# Out:
# <ipython-input-42-36b7b9d9b23d>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_players.append(df_players)
#    Jugador  Goles  Nueva_columna  Rango
# 1    Navas      2            NaN      0
# 7   Mbappe    200            NaN      1
# 10  Neymar    150            NaN      2
# 30   Messi    500            NaN      3
# 1    Navas      2            NaN      0
# 7   Mbappe    200            NaN      1
# 10  Neymar    150            NaN      2
# 30   Messi    500            NaN      3

# %% [markdown]
# # Manejo de datos nulos

# %%
dict = {'Col1':[1,2,3,np.nan],
'Col2':[4, np.nan,6,7],
'Col3':['a','b','c', None]}

# %%
df = pd.DataFrame(dict)

# %%
df.isnull()
# Out:
#     Col1   Col2   Col3
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3   True  False   True

# %%
df.isnull()*1
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %%
df.fillna('Missing')
# Out:
#       Col1     Col2     Col3
# 0      1.0      4.0        a
# 1      2.0  Missing        b
# 2      3.0      6.0        c
# 3  Missing      7.0  Missing

# %%
df.fillna(df.mean())
# Out:
# <ipython-input-48-a2478f315f9e>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean())
#    Col1      Col2  Col3
# 0   1.0  4.000000     a
# 1   2.0  5.666667     b
# 2   3.0  6.000000     c
# 3   2.0  7.000000  None

# %%
df.interpolate()
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %%
df.dropna()
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c

# %% [markdown]
# # Filtrado por condiciones

# %%
mayor = df_players['Goles'] > 100
mayor
# Out:
# 1     False
# 7      True
# 10     True
# 30     True
# Name: Goles, dtype: bool

# %%
df_players[mayor]
# Out:
#    Jugador  Goles  Nueva_columna  Rango
# 7   Mbappe    200            NaN      1
# 10  Neymar    150            NaN      2
# 30   Messi    500            NaN      3

# %% [markdown]
# # Funciones principales de Pandas

# %%
df_players.head(2)
# Out:
#   Jugador  Goles  Nueva_columna  Rango
# 1   Navas      2            NaN      0
# 7  Mbappe    200            NaN      1

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 30
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Jugador        4 non-null      object
#  1   Goles          4 non-null      int64
#  2   Nueva_columna  0 non-null      float64
#  3   Rango          4 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 332.0+ bytes

# %%
df_players.describe()
# Out:
#             Goles  Nueva_columna     Rango
# count    4.000000            0.0  4.000000
# mean   213.000000            NaN  1.500000
# std    208.988038            NaN  1.290994
# min      2.000000            NaN  0.000000
# 25%    113.000000            NaN  0.750000
# 50%    175.000000            NaN  1.500000
# 75%    275.000000            NaN  2.250000
# max    500.000000            NaN  3.000000

# %%
df_players.tail(2)
# Out:
#    Jugador  Goles  Nueva_columna  Rango
# 10  Neymar    150            NaN      2
# 30   Messi    500            NaN      3

# %%
df_players.memory_usage(deep=True)
# Out:
# Index            204
# Jugador          250
# Goles             32
# Nueva_columna     32
# Rango             32
# dtype: int64

# %%
# Muestra cuantos datos hay de cada jugador
df_players['Jugador'].value_counts()
# Out:
# Navas     1
# Mbappe    1
# Neymar    1
# Messi     1
# Name: Jugador, dtype: int64

# %%
# Eliminar registros duplicados
df_players.drop_duplicates()
# Out:
#    Jugador  Goles  Nueva_columna  Rango
# 1    Navas      2            NaN      0
# 7   Mbappe    200            NaN      1
# 10  Neymar    150            NaN      2
# 30   Messi    500            NaN      3

# %%
df_players.sort_values('Goles')
# Out:
#    Jugador  Goles  Nueva_columna  Rango
# 1    Navas      2            NaN      0
# 10  Neymar    150            NaN      2
# 7   Mbappe    200            NaN      1
# 30   Messi    500            NaN      3

# %%
df_players.sort_values('Goles', ascending=False)
# Out:
#    Jugador  Goles  Nueva_columna  Rango
# 30   Messi    500            NaN      3
# 7   Mbappe    200            NaN      1
# 10  Neymar    150            NaN      2
# 1    Navas      2            NaN      0

# %% [markdown]
# # groupby

# %%
df_players.groupby('Jugador').count()
# Out:
#          Goles  Nueva_columna  Rango
# Jugador
# Mbappe       1              0      1
# Messi        1              0      1
# Navas        1              0      1
# Neymar       1              0      1

# %%
df_players.groupby('Jugador').median()
# Out:
#          Goles  Nueva_columna  Rango
# Jugador
# Mbappe   200.0            NaN    1.0
# Messi    500.0            NaN    3.0
# Navas      2.0            NaN    0.0
# Neymar   150.0            NaN    2.0

# %%
df_players.groupby('Jugador').sum().loc['Messi']
# Out:
# Goles            500.0
# Nueva_columna      0.0
# Rango              3.0
# Name: Messi, dtype: float64

# %%
df_players.groupby('Jugador').agg(['min','max'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f67f6a27b66e> in <cell line: 1>()
# ----> 1 df_players.groupby('Jugador').agg(['min','max'])
#
# NameError: name 'df_players' is not defined

# %% [markdown]
# # Merge y Concat

# %%
df1 = pd.DataFrame({'A':['A0', 'A1', 'A2','A3'],
        'B':['B0', 'B1', 'B2','B3'],
	'C':['C0', 'C1', 'C2','C3'],
	'D':['D0', 'D1', 'D2','D3']})


df2 = pd.DataFrame({'A':['A4', 'A5', 'A6','A7'],
	'B':['B4', 'B5', 'B6','B7'],
	'C':['C4', 'C5', 'C6','C7'],
	'D':['D4', 'D5', 'D6','D7']})

# %%
pd.concat([df1,df2])
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
pd.concat([df1,df2], ignore_index= True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2], axis = 1)
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# ## Merge

# %%
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
izq.merge(der)
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %%
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key_2' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
izq.merge(der, left_on = 'key', right_on='key_2')
# Out:
#   key   A   B key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2
# 3  k3  A3  B3    k3  C3  D3

# %%
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key_2' : ['k0', 'k1', 'k2',np.nan],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
izq.merge(der, left_on = 'key', right_on='key_2', how='left')
# Out:
#   key   A   B key_2    C    D
# 0  k0  A0  B0    k0   C0   D0
# 1  k1  A1  B1    k1   C1   D1
# 2  k2  A2  B2    k2   C2   D2
# 3  k3  A3  B3   NaN  NaN  NaN

# %% [markdown]
# # Join

# %%
izq = pd.DataFrame({'A': ['A0','A1','A2'],
  'B':['B0','B1','B2']},
  index=['k0','k1','k2'])

der = pd.DataFrame({'C': ['C0','C1','C2'],
  'D':['D0','D1','D2']},
  index=['k0','k2','k3'])

# %%
izq.join(der)
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
izq.join(der, how = 'outer')
# Out:
#       A    B    C    D
# k0   A0   B0   C0   D0
# k1   A1   B1  NaN  NaN
# k2   A2   B2   C1   D1
# k3  NaN  NaN   C2   D2

# %% [markdown]
# # Apply

# %%
def two_times(value):
    return value * 2

# %%
df_players['Goles'].apply(two_times)
# Out:
# 1        4
# 7      400
# 10     300
# 30    1000
# Name: Goles, dtype: int64

# %%
df_players['Goles 2'] = df_players['Goles'].apply(two_times)
df_players
# Out:
#    Jugador  Altura  Goles  Goles 2
# 1    Navas   183.0     12       24
# 7   Mbappe   170.0   1200     2400
# 10  Neymar   170.0    900     1800
# 30   Messi   163.0   3000     6000

# %%
df_players['Goles 2'] = df_players['Goles'].apply(lambda x: x* 3)
df_players
# Out:
#    Jugador  Altura  Goles  Goles 2
# 1    Navas   183.0     12       36
# 7   Mbappe   170.0   1200     3600
# 10  Neymar   170.0    900     2700
# 30   Messi   163.0   3000     9000
